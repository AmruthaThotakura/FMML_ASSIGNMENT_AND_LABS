# %% [markdown]
# <a href="https://colab.research.google.com/github/AmruthaThotakura/FMML_ASSIGNMENT_AND_LABS/blob/main/FMML_Aug'22_M9_L2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Foundation of Modern Machine Learning
# ## Module 9: Neural Networks
# ## Lab 2: Using MLP for multiclass classification
# #### Module Coordinator: Shantanu Agrawal

# %% [markdown]
# Till now, we got to know what is MLP, how it can be used for classification. We have done the single class classification in the previous lab session.
#
# In this notebook we will try to use an MLP for multiclass classification on the iris dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Data preparation

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the iris dataset
iris = load_iris()
X = iris['data']
y = iris['target']
names = iris['target_names']
feature_names = iris['feature_names']

# Scale data to have mean 0 and variance 1
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data set into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=2)

# %% [markdown]
# # Visualising dataset

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax1.plot(X_plot[:, 0], X_plot[:, 1],
             linestyle='none',
             marker='o',
             label=target_name)
ax1.set_xlabel(feature_names[0])
ax1.set_ylabel(feature_names[1])
ax1.axis('equal')
ax1.legend();

for target, target_name in enumerate(names):
    X_plot = X[y == target]
    ax2.plot(X_plot[:, 2], X_plot[:, 3],
             linestyle='none',
             marker='o',
             label=target_name)
ax2.set_xlabel(feature_names[2])
ax2.set_ylabel(feature_names[3])
ax2.axis('equal')
ax2.legend();

# %% [markdown]
# # Observing the dataset
#
# Thus, we can observe the dataset and see that there are *3 classes, setosa, versicolor, and virginica*.
#
# There are *4 features, sepal width, sepal length, petal width, petal length*.

# %% [markdown]
# # MLP for multiclass classification

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.autograd import Variable
import tqdm

# %%
# Defining the model architecture
class Model(nn.Module):
    def __init__(self, input_dim):
        super(Model, self).__init__()
        self.layer1 = nn.Linear(input_dim, 50)
        self.layer2 = nn.Linear(50, 50)
        self.layer3 = nn.Linear(50, 3)

    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        x = F.softmax(self.layer3(x), dim=1)
        return x

# %%
# Instantiating the model, using Adam optimiser, and Cross Entropy Loss, which is quite commonlu used for classification tasks.
model     = Model(X_train.shape[1])
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn   = nn.CrossEntropyLoss()

# %% [markdown]
# # Train the model

# %%
# Train for 100 epochs
EPOCHS  = 100
X_train = torch.from_numpy(X_train).float()
X_test= torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test)
y_train = torch.from_numpy(y_train)


loss_list     = np.zeros((EPOCHS,))
accuracy_list = np.zeros((EPOCHS,))

for epoch in tqdm.trange(EPOCHS):
    y_pred = model(X_train)
    loss = loss_fn(y_pred, y_train)
    loss_list[epoch] = loss.item()

    # Zero gradients
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    with torch.no_grad():
        y_pred = model(X_test)
        correct = (torch.argmax(y_pred, dim=1) == y_test).type(torch.FloatTensor)
        accuracy_list[epoch] = correct.mean()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 231.57it/s]

# %% [markdown]
# # Plot training progress

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(12, 6), sharex=True)

ax1.plot(accuracy_list)
ax1.set_ylabel("validation accuracy")
ax2.plot(loss_list)
ax2.set_ylabel("validation loss")
ax2.set_xlabel("epochs");

# %% [markdown]
# # Experiment with the neural network architecture
#
#
# 1.   Try changing the number of hidden layers.
# 2.   Try changing the number of neurons in the hidden layer.
# 3.   Try using a different activation function.                                                                 Certainly! Let's experiment with different neural network architectures by changing the number of hidden layers, the number of neurons in the hidden layers, and using different activation functions.
#
# python
# Copy code
# from sklearn.neural_network import MLPClassifier
#
# # Define training data
# X = [[-1, -1], [-1, 1], [1, -1], [1, 1]]  # Input features
# # Target outputs for AND, OR, and NOR gates in -1/+1 logic
# y_and = [-1, -1, -1, 1]
# y_or = [-1, 1, 1, 1]
# y_nor = [1, -1, -1, -1]
#
# # Experimenting with different architectures
# architectures = [
#     {'hidden_layer_sizes': (2,), 'activation': 'logistic'},  # Single layer with 2 neurons, logistic activation
#     {'hidden_layer_sizes': (4,), 'activation': 'logistic'},  # Single layer with 4 neurons, logistic activation
#     {'hidden_layer_sizes': (2, 2), 'activation': 'logistic'},  # Two layers with 2 neurons each, logistic activation
#     {'hidden_layer_sizes': (4, 2), 'activation': 'relu'},  # Two layers with 4 and 2 neurons, ReLU activation
#     {'hidden_layer_sizes': (4, 4), 'activation': 'tanh'},  # Two layers with 4 neurons each, tanh activation
# ]
#
# for i, config in enumerate(architectures):
#     print(f"Architecture {i+1}:")
#     classifier_and = MLPClassifier(**config, max_iter=1000)
#     classifier_or = MLPClassifier(**config, max_iter=1000)
#     classifier_nor = MLPClassifier(**config, max_iter=1000)
#
#     # Train the classifiers
#     classifier_and.fit(X, y_and)
#     classifier_or.fit(X, y_or)
#     classifier_nor.fit(X, y_nor)
#
#     # Test the classifiers
#     test_cases = [[-1, -1], [-1, 1], [1, -1], [1, 1]]
#
#     print("AND Gate:")
#     for test_case in test_cases:
#         prediction = classifier_and.predict([test_case])
#         print(f"Input: {test_case}, Output: {prediction}")
#
#     print("\nOR Gate:")
#     for test_case in test_cases:
#         prediction = classifier_or.predict([test_case])
#         print(f"Input: {test_case}, Output: {prediction}")
#
#     print("\nNOR Gate:")
#     for test_case in test_cases:
#         prediction = classifier_nor.predict([test_case])
#         print(f"Input: {test_case}, Output: {prediction}")
#
#     print("\n")
# In this code:
#
# We define different neural network architectures with varying numbers of hidden layers, neurons per layer, and activation functions.
# We loop through each architecture configuration, train an MLP classifier for AND, OR, and NOR gates, and test its performance.
# We print the output for each gate using the trained classifiers with the specified architectures.
# You can observe how changing the architecture affects the performance of the classifiers for different logic gates. The choice of activation function and the number of layers/neurons can significantly impact the model's ability to learn and generalize from the data. Experimenting with different configurations can help find the optimal architecture for the task at hand.
#
#
#
#
#
#
#
#
#
#
#
# Can you observe any changes?
